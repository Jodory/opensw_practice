# %%
# !pip install transformers[sentencepiece]
# Out:
# ...
#      ---------------------------------------- 0.0/123.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/123.5 kB ? eta -:--:--
#      --------- --------------------------- 30.7/123.5 kB 660.6 kB/s eta 0:00:01
#      ----------------------------- --------- 92.2/123.5 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 123.5/123.5 kB 1.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB 1.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/977.6 kB ? eta -:--:--
#      - ----------------------------------- 41.0/977.6 kB 991.0 kB/s eta 0:00:01
#      ------ ------------------------------- 174.1/977.6 kB 2.1 MB/s eta 0:00:01
# ...

# %%
from transformers import pipleline

classifier = pipleline('sentiment-analysis')
classifier(
    [
        "I've been waiting for a HuggingFace course my whole life.",
        "I hate this so much!",
    ]
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# g:\다른 컴퓨터\Home\조성운_노트북\경기대학교공부\4학년\2023_2학기_수업\금_오픈소스SW실습\opensw\huggingface_start.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/g%3A/%EB%8B%A4%EB%A5%B8%20%EC%BB%B4%ED%93%A8%ED%84%B0/Home/%EC%A1%B0%EC%84%B1%EC%9A%B4_%EB%85%B8%ED%8A%B8%EB%B6%81/%EA%B2%BD%EA%B8%B0%EB%8C%80%ED%95%99%EA%B5%90%EA%B3%B5%EB%B6%80/4%ED%95%99%EB%85%84/2023_2%ED%95%99%EA%B8%B0_%EC%88%98%EC%97%85/%EA%B8%88_%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4SW%EC%8B%A4%EC%8A%B5/opensw/huggingface_start.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from transformers import pipleline
# ...
